# %%
# plot decision tree
from numpy import loadtxt
from xgboost import XGBClassifier
from xgboost import plot_tree
import matplotlib.pyplot as plt

def ceate_feature_map(features):
    outfile = open('xgb.fmap', 'w')
    i = 0
    for feat in features:
        outfile.write('{0}\t{1}\tq\n'.format(i, feat))
        i = i + 1
    outfile.close()
# ceate_feature_map(X_train.columns)

# load data
dataset = loadtxt('pima-indians-diabetes.data.csv', delimiter=",")
# split data into X and y
X = dataset[:,0:8]
y = dataset[:,8]
# fit model no training data
model = XGBClassifier()
model.fit(X, y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
# plot single tree
# plot_tree(clf, num_trees=0, fmap='xgb.fmap')
plot_tree(model, num_trees=0)
fig = plt.gcf()
fig.set_size_inches(50, 50)
fig.savefig("./tree_0.png", format='png',bbox_inches='tight')
plt.show()

# %%
# plot single tree
# plot_tree(clf, num_trees=0, fmap='xgb.fmap')
plot_tree(model, num_trees=1)
fig = plt.gcf()
fig.set_size_inches(50, 50)
fig.savefig("./tree_1.png", format='png',bbox_inches='tight')
plt.show()

# %%
# plot single tree
# plot_tree(clf, num_trees=0, fmap='xgb.fmap')
plot_tree(model, num_trees=99)
fig = plt.gcf()
fig.set_size_inches(50, 50)
fig.savefig("./tree_99.png", format='png',bbox_inches='tight')
plt.show()
